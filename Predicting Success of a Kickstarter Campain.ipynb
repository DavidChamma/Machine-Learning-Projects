# %%
#All packages

import pandas as pd
import numpy as np
from sklearn.preprocessing import Imputer

# %% [markdown]
# #### Dataset importation :

# %%
#Dataset importation
dataset = pd.read_csv("ks-projects-201801.csv",delimiter =",")

# %% [markdown]
# ## 1- Dataset Description :

# %% [markdown]
# In our project, we will be using a data set on Kickstarter campaign collected from kaggle.com. The set contains 378 661 observations and 15 different features:

# %% [markdown]
# ## 2- Dataset Exploration :

# %%
dataset.shape
# Out:
# (378661, 15)

# %% [markdown]
# Our dataset contains 378 661 observations (lines) and 15 different features (columns).

# %%
dataset.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# 1  2017-09-02 04:43:57   2421.0    failed       15      US        100.0
# 2  2013-01-12 00:20:50    220.0    failed        3      US        220.0
# 3  2012-03-17 03:24:11      1.0    failed        1      US          1.0
# 4  2015-07-04 08:35:03   1283.0  canceled       14      US       1283.0
#
#    usd_pledged_real  usd_goal_real
# 0               0.0        1533.95
# 1            2421.0       30000.00
# 2             220.0       45000.00
# 3               1.0        5000.00
# 4            1283.0       19500.00

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378661 entries, 0 to 378660
# Data columns (total 15 columns):
# ID                  378661 non-null int64
# name                378657 non-null object
# category            378661 non-null object
# main_category       378661 non-null object
# currency            378661 non-null object
# deadline            378661 non-null object
# goal                378661 non-null float64
# launched            378661 non-null object
# pledged             378661 non-null float64
# state               378661 non-null object
# backers             378661 non-null int64
# country             378661 non-null object
# usd pledged         374864 non-null float64
# usd_pledged_real    378661 non-null float64
# usd_goal_real       378661 non-null float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 43.3+ MB

# %% [markdown]
# The response variable “state” is object, and the predictors are mixed with integer, float and object variables.

# %%
dataset.describe()
# Out:
#                  ID          goal       pledged        backers   usd pledged  \
# count  3.786610e+05  3.786610e+05  3.786610e+05  378661.000000  3.748640e+05
# mean   1.074731e+09  4.908079e+04  9.682979e+03     105.617476  7.036729e+03
# std    6.190862e+08  1.183391e+06  9.563601e+04     907.185035  7.863975e+04
# min    5.971000e+03  1.000000e-02  0.000000e+00       0.000000  0.000000e+00
# 25%    5.382635e+08  2.000000e+03  3.000000e+01       2.000000  1.698000e+01
# 50%    1.075276e+09  5.200000e+03  6.200000e+02      12.000000  3.947200e+02
# 75%    1.610149e+09  1.600000e+04  4.076000e+03      56.000000  3.034090e+03
# max    2.147476e+09  1.000000e+08  2.033899e+07  219382.000000  2.033899e+07
#
#        usd_pledged_real  usd_goal_real
# count      3.786610e+05   3.786610e+05
# mean       9.058924e+03   4.545440e+04
# std        9.097334e+04   1.152950e+06
# min        0.000000e+00   1.000000e-02
# 25%        3.100000e+01   2.000000e+03
# 50%        6.243300e+02   5.500000e+03
# 75%        4.050000e+03   1.550000e+04
# max        2.033899e+07   1.663614e+08

# %% [markdown]
# Let's ckeck if we have missing values in our dataset:

# %%
dataset.isnull().sum(axis=0) #count the number of MV per column
# Out:
# ID                     0
# name                   4
# category               0
# main_category          0
# currency               0
# deadline               0
# goal                   0
# launched               0
# pledged                0
# state                  0
# backers                0
# country                0
# usd pledged         3797
# usd_pledged_real       0
# usd_goal_real          0
# dtype: int64

# %% [markdown]
# We have missing values in 'name' column and 'usd pledge'column.

# %%
#Back-up Dataset :
original_dataset=dataset

# %% [markdown]
# ## 3- Data Engeeniring :

# %% [markdown]
# #### 3.1- Subset dataset:

# %% [markdown]
# We decide to extract Date, Hours, Minutes & Seconds from 'launched'column. We then create 4 new columns 'date_of_lunch', 'hours', 'minutes' & 'seconds' filled by the extracted information.

# %%
v = dataset.launched.str.split() #split 'launched' in Date/Hours/Minute/Seconds 
dataset['date_of_launch'] = v.str[0] #We create a new column 'date_of_lunch'that we fill with Date
dataset[['hours', 'minutes', 'seconds']] = ( pd.to_timedelta(v.str[-1]).dt.components.iloc[:, 1:4]) #We create 3 new columns which will be filled by Hours, Minutes & Seconds.

# %%
dataset['date_of_launch'] = pd.to_datetime(dataset['date_of_launch']) #Transform it as date type
dataset['deadline'] = pd.to_datetime(dataset['deadline']) #Transform it as date type

# %% [markdown]
# We extract Year, Month and Day from 'date_of_launch' column. We then create 3 new columns 'Year', 'Month'& 'Day' filled by the extracted information.

# %%
dataset['Year'] = dataset['date_of_launch'].dt.year
dataset['Month'] = dataset['date_of_launch'].dt.month
dataset['Day'] = dataset['date_of_launch'].dt.day

# %%
dataset=dataset.drop("launched",axis=1) #Delete 'launched' column

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378661 entries, 0 to 378660
# Data columns (total 21 columns):
# ID                  378661 non-null int64
# name                378657 non-null object
# category            378661 non-null object
# main_category       378661 non-null object
# currency            378661 non-null object
# deadline            378661 non-null datetime64[ns]
# goal                378661 non-null float64
# pledged             378661 non-null float64
# state               378661 non-null object
# backers             378661 non-null int64
# country             378661 non-null object
# usd pledged         374864 non-null float64
# usd_pledged_real    378661 non-null float64
# usd_goal_real       378661 non-null float64
# date_of_launch      378661 non-null datetime64[ns]
# hours               378661 non-null int64
# minutes             378661 non-null int64
# seconds             378661 non-null int64
# Year                378661 non-null int64
# Month               378661 non-null int64
# Day                 378661 non-null int64
# dtypes: datetime64[ns](2), float64(5), int64(8), object(6)
# memory usage: 60.7+ MB

# %% [markdown]
# We have now 21 features (columns) in our dataframe.

# %% [markdown]
# Our dataset contains 378 661 observation. In order to predict the success of Kickstarter campaign, we choose to select only some observations. So, we decide to take into account only 2017's Kickstarter campaign.

# %%
year=[2017,2017]
dataset = dataset[dataset.Year.isin(year)]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52200 entries, 1 to 378654
# Data columns (total 21 columns):
# ID                  52200 non-null int64
# name                52200 non-null object
# category            52200 non-null object
# main_category       52200 non-null object
# currency            52200 non-null object
# deadline            52200 non-null datetime64[ns]
# goal                52200 non-null float64
# pledged             52200 non-null float64
# state               52200 non-null object
# backers             52200 non-null int64
# country             52200 non-null object
# usd pledged         52200 non-null float64
# usd_pledged_real    52200 non-null float64
# usd_goal_real       52200 non-null float64
# date_of_launch      52200 non-null datetime64[ns]
# hours               52200 non-null int64
# minutes             52200 non-null int64
# seconds             52200 non-null int64
# Year                52200 non-null int64
# Month               52200 non-null int64
# Day                 52200 non-null int64
# dtypes: datetime64[ns](2), float64(5), int64(8), object(6)
# memory usage: 8.8+ MB

# %% [markdown]
# We now have 52 200 observations.

# %% [markdown]
# #### 3.2- Create new columns:

# %% [markdown]
# We create a new column 'length_of_campain' which corresponds to the interval of time between launching and the deadline.

# %%
dataset['length_of_campain'] = dataset['deadline'].sub(dataset['date_of_launch'], axis=0)

# %% [markdown]
# We need to convert 'Length_of_campaign' values as integers, indeed they used to be numpy.timedelta64 type so it was impossible to apply them to our models.

# %%
dataset['length_of_campain']=dataset['length_of_campain'].dt.days

# %% [markdown]
# We're creating 4 new features : Average amount of money pledge per category, Average goal company hopes to reach per category, average number of backers per category and "Competitors", that accounts the number of competition of the i project based on its main category and on the launch month.

# %%
#Creating 4 new features
dataset.loc[:, 'Average_Pledge_Per_Category']= 0
dataset.loc[:, 'Average_Goal_Per_Category']=0
dataset.loc[:, 'Average_NumberofBackers_Per_Category']=0
dataset.loc[:, 'Competitors']=0

# %% [markdown]
# Now we fill those columns with the right values

# %%
#Mean of pledge per category
dataset["Average_Pledge_Per_Category"]=pd.DataFrame(dataset.groupby(['main_category'])['usd_pledged_real'].transform(lambda x: x.mean()))
dataset["Average_Goal_Per_Category"]=pd.DataFrame(dataset.groupby(['main_category'])['usd_goal_real'].transform(lambda x: x.mean()))
dataset["Average_NumberofBackers_Per_Category"]=round(pd.DataFrame(dataset.groupby(['main_category'])['backers'].transform(lambda x: x.mean())))
dataset["Competitors"] = dataset.groupby(['main_category','Month']).transform(lambda x: x.count())

# %% [markdown]
# We got too many decimals on the amount of our averages. Thus,we're rounding the numbers.

# %%
dataset.Average_Pledge_Per_Category = round(dataset.Average_Pledge_Per_Category)
dataset.Average_Goal_Per_Category = round(dataset.Average_Goal_Per_Category)

# %% [markdown]
# Creating a Difference column which corresponds to USD goal real - Average goal per category

# %%
dataset.loc[:, 'Difference']= 0
dataset.Difference = dataset.usd_goal_real - dataset.Average_Goal_Per_Category

# %% [markdown]
# Thanks to Difference column we're creating a new feature which will precise if the company tried to raise more than the average for its category or in contrary less than the average for its category.

# %%
#Defining an empty list 
Is_Above_Average = []
#Fill the list.
for row in dataset['Difference']:
    if row > 0 :
        Is_Above_Average.append(1)
    else :
        Is_Above_Average.append(0)
        
dataset['Is_Above_Average'] = Is_Above_Average

# %% [markdown]
# Now we remove Difference column

# %%
dataset.drop(columns = ["Difference"], inplace = True)

# %% [markdown]
# We create another column called "Day_of_the_week", for each project we indicated the day of the week at which it has been launched.

# %%
import datetime
datetime.datetime.strptime('2017-09-03', '%Y-%M-%d').strftime('%A')
dataset.loc[:, 'Day_of_the_week']=0
dataset['Day_of_the_week'] = pd.to_datetime(dataset['date_of_launch'])
dataset['Day_of_the_week'] = dataset['Day_of_the_week'].dt.weekday_name
dataset.head()
# Out:
#             ID                                               name  \
# 1   1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 14  1000057089  Tombstone: Old West tabletop game and miniatur...
# 21  1000081649                   MikeyJ clothing brand fundraiser
# 29   100011318                      My Moon - Animated Short Film
# 40  1000149007             Unschooling To University Book Project
#
#           category main_category currency   deadline     goal   pledged  \
# 1   Narrative Film  Film & Video      USD 2017-11-01  30000.0   2421.00
# 14  Tabletop Games         Games      GBP 2017-05-03   5000.0  94175.00
# 21   Childrenswear       Fashion      AUD 2017-09-07   2500.0      1.00
# 29       Animation  Film & Video      USD 2017-05-03  50000.0  57577.31
# 40      Nonfiction    Publishing      CAD 2018-01-19   3000.0    592.00
#
#          state  backers       ...         Year  Month  Day  length_of_campain  \
# 1       failed       15       ...         2017      9    2                 60
# 14  successful      761       ...         2017      4    5                 28
# 21      failed        1       ...         2017      8    8                 30
# 29  successful      840       ...         2017      4    3                 30
# 40        live       24       ...         2017     11   20                 60
#
#    Average_Pledge_Per_Category  Average_Goal_Per_Category  \
# 1                       5808.0                   164850.0
# 14                     22930.0                    21266.0
# 21                      6042.0                    19000.0
# 29                      5808.0                   164850.0
# 40                      4726.0                    15463.0
#
#     Average_NumberofBackers_Per_Category  Competitors  Is_Above_Average  \
# 1                                   60.0          397                 0
# 14                                 317.0          592                 0
# 21                                  57.0          396                 0
# 29                                  60.0          513                 0
# 40                                  78.0          476                 0
#
#     Day_of_the_week
# 1          Saturday
# 14        Wednesday
# 21          Tuesday
# 29           Monday
# 40           Monday
#
# [5 rows x 28 columns]

# %% [markdown]
# Now we're transforming it as a categorical variable, with Sunday = 1...Saturday = 6

# %%
dataset['Day_of_the_week'].replace(["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],[1,2,3,4,5,6,7], inplace=True)

# %% [markdown]
# We created another column called "Number_of_Words" that count the number of words a project has.
# We'll check with the correlation heatmap if it has an impact on the state.

# %%
dataset.loc[:,'Name_Number_Letters']=dataset['name']
dataset['Name_Number_Letters']=dataset['Name_Number_Letters'].str.len()

# %% [markdown]
# We created another column called "Name_Number_Letters" that count the number of letters a project has. We'll check with the correlation heatmap if it has an impact on the state.

# %%
dataset.loc[:, 'Number_of_words']=dataset['name']
dataset['Number_of_words']=dataset['Number_of_words'].str.strip().str.split('[\W_]+')
dataset['Number_of_words']=dataset['Number_of_words'].str.len()
dataset.head()
# Out:
#             ID                                               name  \
# 1   1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 14  1000057089  Tombstone: Old West tabletop game and miniatur...
# 21  1000081649                   MikeyJ clothing brand fundraiser
# 29   100011318                      My Moon - Animated Short Film
# 40  1000149007             Unschooling To University Book Project
#
#           category main_category currency   deadline     goal   pledged  \
# 1   Narrative Film  Film & Video      USD 2017-11-01  30000.0   2421.00
# 14  Tabletop Games         Games      GBP 2017-05-03   5000.0  94175.00
# 21   Childrenswear       Fashion      AUD 2017-09-07   2500.0      1.00
# 29       Animation  Film & Video      USD 2017-05-03  50000.0  57577.31
# 40      Nonfiction    Publishing      CAD 2018-01-19   3000.0    592.00
#
#          state  backers       ...        Day  length_of_campain  \
# 1       failed       15       ...          2                 60
# 14  successful      761       ...          5                 28
# 21      failed        1       ...          8                 30
# 29  successful      840       ...          3                 30
# 40        live       24       ...         20                 60
#
#     Average_Pledge_Per_Category  Average_Goal_Per_Category  \
# 1                        5808.0                   164850.0
# 14                      22930.0                    21266.0
# 21                       6042.0                    19000.0
# 29                       5808.0                   164850.0
# 40                       4726.0                    15463.0
#
#    Average_NumberofBackers_Per_Category  Competitors  Is_Above_Average  \
# 1                                  60.0          397                 0
# 14                                317.0          592                 0
# 21                                 57.0          396                 0
# 29                                 60.0          513                 0
# 40                                 78.0          476                 0
#
#     Day_of_the_week  Name_Number_Letters  Number_of_words
# 1                 7                   45                8
# 14                4                   57               10
# 21                3                   32                4
# 29                2                   29                5
# 40                2                   38                5
#
# [5 rows x 30 columns]

# %% [markdown]
# ## 4- Data Visualization:

# %% [markdown]
# We plotted those days against the outputs "success" "failure" to check if one can notice a trend. Indeed, some days are more "propice" than others.

# %%
import matplotlib.pyplot as plt
plt.hist(x=dataset['Day_of_the_week'], bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Day Of Week')
plt.ylabel('Frequency')
plt.title('My Very Own Histogram')
plt.text(23, 45, r'$\mu=15, b=3$')
plt.show()

# %%
import seaborn as sns
sns.countplot(x="hours",hue = 'state' ,data=dataset)

# %%
import plotly.offline as offline
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly import *
from plotly import tools
from plotly.plotly import iplot
import plotly.plotly as py
import plotly
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
groupby_main_category = dataset.groupby('main_category').mean()
trace1 = go.Bar(
            x=groupby_main_category['Average_NumberofBackers_Per_Category'].index,
            y=groupby_main_category['Average_NumberofBackers_Per_Category'].values,
            opacity=0.65
        )

trace2 = go.Bar(
            x=groupby_main_category['Average_Pledge_Per_Category'].index,
            y=groupby_main_category['Average_Pledge_Per_Category'].values,
            opacity=0.65
        )

trace3 = go.Bar(
            x=groupby_main_category['Average_Goal_Per_Category'].index,
            y=groupby_main_category['Average_Goal_Per_Category'].values,
            opacity=0.65
        )

trace4 = go.Bar(
            x=groupby_main_category['length_of_campain'].index,
            y=groupby_main_category['length_of_campain'].values,
            opacity=0.65
        )
fig = tools.make_subplots(rows=2, cols=2, subplot_titles=('Backers', 'Average Money Pledged','Average Goal Amount','Duration(days)'))
fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)
fig.append_trace(trace3, 2, 1)
fig.append_trace(trace4, 2, 2)

fig['layout'].update(height=600, width=900, title='Distributions according to Main Category of Successful Campaigns')

iplot(fig)
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]
# [ (2,1) x3,y3 ]  [ (2,2) x4,y4 ]
# <div id="3b3dbfe5-1290-4c8e-9e62-1a6156675265" style="height: 600px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3b3dbfe5-1290-4c8e-9e62-1a6156675265", [{"opacity": 0.65, "x": ["Art", "Comics", "Crafts", "Dance", "Design", "Fashion", "Film & Video", "Food", "Games", "Journalism", "Music", "Photography", "Publishing", "Technology", "Theater"], "y": [59.0, 134.0, 28.0, 37.0, 244.0, 57.0, 60.0, 52.0, 317.0, 40.0, 59.0, 61.0, 78.0, 155.0, 42.0], "type": "bar", "uid": "28af0023-8cb4-47d0-8692-2e1c424cd075", "xaxis": "x", "yaxis": "y"}, {"opacity": 0.65, "x": ["Art", "Comics", "Crafts", "Dance", "Design", "Fashion", "Film & Video", "Food", "Games", "Journalism", "Music", "Photography", "Publishing", "Technology", "Theater"], "y": [4121.0, 6095.0, 1927.0, 3435.0, 27676.0, 6042.0, 5808.0, 5629.0, 22930.0, 2926.0, 4312.0, 6696.0, 4726.0, 22971.0, 3755.0], "type": "bar", "uid": "fd4ca344-b7e6-4415-9764-08bec52ccee9", "xaxis": "x2", "yaxis": "y2"}, {"opacity": 0.65, "x": ["Art", "Comics", "Crafts", "Dance", "Design", "Fashion", "Film & Video", "Food", "Games", "Journalism", "Music", "Photography", "Publishing", "Technology", "Theater"], "y": [43883.0, 6358.0, 8087.0, 9679.0, 24748.0, 19000.0, 164850.0, 29399.0, 21266.0, 36877.0, 17327.0, 11526.0, 15463.0, 66046.0, 23503.0], "type": "bar", "uid": "51e58c20-9d67-4b3d-9864-d95b1ad8fb17", "xaxis": "x3", "yaxis": "y3"}, {"opacity": 0.65, "x": ["Art", "Comics", "Crafts", "Dance", "Design", "Fashion", "Film & Video", "Food", "Games", "Journalism", "Music", "Photography", "Publishing", "Technology", "Theater"], "y": [29.91012658227848, 31.157842157842158, 30.640077821011673, 32.3027027027027, 33.84657347425844, 31.71686460807601, 33.49664429530201, 34.08803258145363, 30.790512113738576, 34.41573033707865, 33.33806876672843, 32.40327237728585, 33.143509706889986, 35.37955228867357, 31.941306755260243], "type": "bar", "uid": "8adc0ade-2847-449e-a7d3-c03d220cb44a", "xaxis": "x4", "yaxis": "y4"}], {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "Backers", "x": 0.225, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "Average Money Pledged", "x": 0.775, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "Average Goal Amount", "x": 0.225, "xanchor": "center", "xref": "paper", "y": 0.375, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "Duration(days)", "x": 0.775, "xanchor": "center", "xref": "paper", "y": 0.375, "yanchor": "bottom", "yref": "paper"}], "xaxis": {"anchor": "y", "domain": [0.0, 0.45]}, "yaxis": {"anchor": "x", "domain": [0.625, 1.0]}, "xaxis2": {"anchor": "y2", "domain": [0.55, 1.0]}, "yaxis2": {"anchor": "x2", "domain": [0.625, 1.0]}, "xaxis3": {"anchor": "y3", "domain": [0.0, 0.45]}, "yaxis3": {"anchor": "x3", "domain": [0.0, 0.375]}, "xaxis4": {"anchor": "y4", "domain": [0.55, 1.0]}, "yaxis4": {"anchor": "x4", "domain": [0.0, 0.375]}, "height": 600, "width": 900, "title": "Distributions according to Main Category of Successful Campaigns"}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script>

# %% [markdown]
# ## 5- Features selection :

# %% [markdown]
# #### 5.1- Elimination of features

# %% [markdown]
# 'usd_goal_real' is too diverse. Thus, we decide to create ranges.

# %%
bins = np.array([0,1000,2000,3000,4000, 5000, 10000, 20000, 30000,40000,50000,60000,70000,80000,90000,100000,200000,300000,400000,500000,1000000,10000000,100000000,1000000000])
dataset['usd_goal_real'] = np.digitize(dataset['usd_goal_real'], bins)

# %% [markdown]
# We remove 'pledged' and 'goal' columns because their information is already in following columns :'usd_pledged_real' and 'usd_goal_real'. We decide to keep 'usd_pledged_real' and 'usd_goal_real' because it's more convenient to compare values in same currency.

# %%
dataset.drop(columns=['pledged'], inplace= True)
dataset.drop(columns=["goal"], inplace= True)

# %% [markdown]
# We remove usd pledged because Usd_pledged_real seems more accurate

# %%
dataset.drop(columns = ["usd pledged"], inplace =True)

# %% [markdown]
# We remove 'category' column because it's too diverse and 'main_category'column contains main information of 'category'

# %%
dataset.drop(columns = ["category"], inplace =True)

# %% [markdown]
# We decide to remove 'seconds','Day'& 'minutes' because it's too diverse and we judge it non relevant for our analysis.

# %%
dataset.drop(columns = ["seconds"], inplace = True)
dataset.drop(columns = ["Day"], inplace = True)
dataset.drop(columns = ["minutes"], inplace = True)

# %% [markdown]
# We remove ligns whose states are live, meaning that the campaign is still running.

# %%
dataset = dataset[dataset.state != "live"]

# %% [markdown]
# We remove ligns whose states are canceled and suspended

# %%
dataset['state'].value_counts()['suspended']/dataset['state'].shape*100
dataset['state'].value_counts()['canceled']/dataset['state'].shape*100
# Out:
# array([11.64260475])

# %% [markdown]
# 11.64% of Kickstarter campaigns of our dataset has been canceled during the campaign. Since the states ‘successful’ and ‘failed’ states comprise of almost 88% of the data-set with the rest of states being in minority, we can focus on the 2 predominant states here for now and so delete rows for canceled and suspended campaigns. Moreover, es raisons pour lesquelles ils ont canceled vont au delà des datas qu'on a.

# %%
dataset= dataset[dataset.state != 'canceled']
dataset=dataset[dataset.state != 'suspended']

# %% [markdown]
# On discretize la colonne 'state'. 0 correspond à failed et 1 a succes.

# %%
dataset["state"]= dataset['state'].map({'failed': 0,'successful': 1})

# %% [markdown]
# We create a new column average sucess per category

# %%
dataset.loc[:, 'Av_Success_Rate_Per_Category']=0
dataset["Av_Success_Rate_Per_Category"]=pd.DataFrame(dataset.groupby(['main_category','Month'])['state'].transform(lambda x: x.mean()))

# %% [markdown]
# Remove 'deadline'and 'date_of_launch'. Toutes les informations sont deja contenues dans month:month of launch et length_of_campaign. De plus, pas sur que le format date soit exploitable pour nos modeles.

# %%
dataset.drop(columns = ["deadline"], inplace =True)
dataset.drop(columns = ["date_of_launch"], inplace =True)

# %% [markdown]
# Remove 'year' column because we decide to take only 2017 Kickstarter campaign

# %%
dataset.drop(columns = ["Year"], inplace =True)

# %% [markdown]
# #### 5.2- Discretization :

# %%
dataset['currency']=dataset['currency'].map({'USD': 1, 'GBP': 2, 'EUR': 3,'CAD': 4,'AUD':5,'MXN':6,'HKD':7,'SEK':8,'SGD':9,'NZD':10,'CHF':11,'DKK':12,'NOK':13,'JPY':14})
dataset['country']=dataset['country'].map({'US': 1, 'GB': 2, 'CA': 3,'AU': 4,'MX':5,'DE':6,'IT':7,'FR':8,'ES':9,'NL':10,'HK':11,'SE':12,'SG':13,'NZ':14,'CH':15,'DK':16,'IE':17,'BE':18,'AT':19,'NO':20,'JP':21,'LU':22})

# %% [markdown]
# Discretize main category

# %%
dataset['main_category']=dataset['main_category'].map({'Games':1,'Technology':2,'Film & Video':3,'Design':4,'Publishing':5,'Music':6,'Fashion':7,'Art':8,'Food':9,'Comics':10,'Crafts':11,'Photography':12,'Theater':13,'Journalism':14,'Dance':15})

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43419 entries, 1 to 378654
# Data columns (total 21 columns):
# ID                                      43419 non-null int64
# name                                    43419 non-null object
# main_category                           43419 non-null int64
# currency                                43419 non-null int64
# state                                   43419 non-null int64
# backers                                 43419 non-null int64
# country                                 43419 non-null int64
# usd_pledged_real                        43419 non-null float64
# usd_goal_real                           43419 non-null int64
# hours                                   43419 non-null int64
# Month                                   43419 non-null int64
# length_of_campain                       43419 non-null int64
# Average_Pledge_Per_Category             43419 non-null float64
# Average_Goal_Per_Category               43419 non-null float64
# Average_NumberofBackers_Per_Category    43419 non-null float64
# Competitors                             43419 non-null int64
# Is_Above_Average                        43419 non-null int64
# Day_of_the_week                         43419 non-null int64
# Name_Number_Letters                     43419 non-null int64
# Number_of_words                         43419 non-null int64
# Av_Success_Rate_Per_Category            43419 non-null float64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 7.3+ MB

# %% [markdown]
# Toutes nos colonnes sont discretizer, a part les noms.

# %% [markdown]
# #### 5.3- Correlation exploration

# %%
import seaborn as sns
# %matplotlib inline

# calculate the correlation matrix
corr = dataset.corr()

# plot the heatmap
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)

# %%
def color_maxs_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if val > 0.6 else 'black'
    return 'color: %s' % color

# %%
corr.style.applymap(color_maxs_red)
# Out:
# <style  type="text/css" >
#     #T_238643b6_fa2d_11e8_b851_4ccc6a844414row0_col0 {
#             color:  red;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row0_col1 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row0_col2 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row0_col3 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row0_col4 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row0_col5 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row0_col6 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row0_col7 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row0_col8 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row0_col9 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row0_col10 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row0_col11 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row0_col12 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row0_col13 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row0_col14 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row0_col15 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row0_col16 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row0_col17 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row0_col18 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row0_col19 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row1_col0 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row1_col1 {
#             color:  red;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row1_col2 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row1_col3 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row1_col4 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row1_col5 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row1_col6 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row1_col7 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row1_col8 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row1_col9 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row1_col10 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row1_col11 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row1_col12 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row1_col13 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row1_col14 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row1_col15 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row1_col16 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row1_col17 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row1_col18 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row1_col19 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row2_col0 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row2_col1 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row2_col2 {
#             color:  red;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row2_col3 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row2_col4 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row2_col5 {
#             color:  red;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row2_col6 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row2_col7 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row2_col8 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row2_col9 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row2_col10 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row2_col11 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row2_col12 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row2_col13 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row2_col14 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row2_col15 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row2_col16 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row2_col17 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row2_col18 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row2_col19 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row3_col0 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row3_col1 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row3_col2 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row3_col3 {
#             color:  red;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row3_col4 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row3_col5 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row3_col6 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row3_col7 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row3_col8 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row3_col9 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row3_col10 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row3_col11 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row3_col12 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row3_col13 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row3_col14 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row3_col15 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row3_col16 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row3_col17 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row3_col18 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row3_col19 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row4_col0 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row4_col1 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row4_col2 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row4_col3 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row4_col4 {
#             color:  red;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row4_col5 {
#             color:  black;
#         }    #T_238643b6_fa2d_11e8_b851_4ccc6a844414row4_col6 {
#             color:  red;
#         }    #T_238643b6_fa2d_11e8_b851_

# %%
cm = sns.light_palette("green", as_cmap=True)
corr.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row0_col0 {
#             background-color:  #008000;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row0_col1 {
#             background-color:  #77c277;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row0_col2 {
#             background-color:  #dcfadc;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row0_col3 {
#             background-color:  #bce8bc;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row0_col4 {
#             background-color:  #d1f4d1;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row0_col5 {
#             background-color:  #d9f8d9;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row0_col6 {
#             background-color:  #d5f6d5;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row0_col7 {
#             background-color:  #bde9bd;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row0_col8 {
#             background-color:  #d3f5d3;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row0_col9 {
#             background-color:  #d9f8d9;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row0_col10 {
#             background-color:  #c6eec6;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row0_col11 {
#             background-color:  #8bcd8b;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row0_col12 {
#             background-color:  #a8dda8;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row0_col13 {
#             background-color:  #8cce8c;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row0_col14 {
#             background-color:  #78c278;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row0_col15 {
#             background-color:  #cbf1cb;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row0_col16 {
#             background-color:  #d2f4d2;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row0_col17 {
#             background-color:  #d1f4d1;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row0_col18 {
#             background-color:  #d3f5d3;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row0_col19 {
#             background-color:  #bce8bc;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row1_col0 {
#             background-color:  #e4fee4;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row1_col1 {
#             background-color:  #008000;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row1_col2 {
#             background-color:  #e5ffe5;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row1_col3 {
#             background-color:  #bae7ba;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row1_col4 {
#             background-color:  #e5ffe5;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row1_col5 {
#             background-color:  #e5ffe5;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row1_col6 {
#             background-color:  #e5ffe5;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row1_col7 {
#             background-color:  #defbde;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row1_col8 {
#             background-color:  #d9f8d9;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row1_col9 {
#             background-color:  #ddfbdd;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row1_col10 {
#             background-color:  #cdf2cd;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row1_col11 {
#             background-color:  #e5ffe5;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row1_col12 {
#             background-color:  #e5ffe5;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row1_col13 {
#             background-color:  #e5ffe5;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row1_col14 {
#             background-color:  #e5ffe5;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row1_col15 {
#             background-color:  #c4edc4;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row1_col16 {
#             background-color:  #d0f3d0;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row1_col17 {
#             background-color:  #cff3cf;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row1_col18 {
#             background-color:  #cef2ce;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row1_col19 {
#             background-color:  #b4e4b4;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row2_col0 {
#             background-color:  #e5ffe5;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row2_col1 {
#             background-color:  #7dc57d;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row2_col2 {
#             background-color:  #008000;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row2_col3 {
#             background-color:  #c2ecc2;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row2_col4 {
#             background-color:  #d7f7d7;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row2_col5 {
#             background-color:  #2b982b;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row2_col6 {
#             background-color:  #daf9da;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row2_col7 {
#             background-color:  #c2ecc2;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row2_col8 {
#             background-color:  #d7f7d7;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row2_col9 {
#             background-color:  #d6f7d6;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row2_col10 {
#             background-color:  #bee9be;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row2_col11 {
#             background-color:  #7fc67f;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row2_col12 {
#             background-color:  #a9dea9;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row2_col13 {
#             background-color:  #84c984;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row2_col14 {
#             background-color:  #71bf71;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row2_col15 {
#             background-color:  #cdf2cd;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row2_col16 {
#             background-color:  #cff3cf;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row2_col17 {
#             background-color:  #cdf2cd;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row2_col18 {
#             background-color:  #d4f6d4;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row2_col19 {
#             background-color:  #c2ebc2;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row3_col0 {
#             background-color:  #e5ffe5;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row3_col1 {
#             background-color:  #76c176;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row3_col2 {
#             background-color:  #e2fde2;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row3_col3 {
#             background-color:  #008000;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row3_col4 {
#             background-color:  #a8dda8;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row3_col5 {
#             background-color:  #e3fee3;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row3_col6 {
#             background-color:  #b8e6b8;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row3_col7 {
#             background-color:  #e5ffe5;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row3_col8 {
#             background-color:  #caf0ca;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row3_col9 {
#             background-color:  #d6f7d6;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row3_col10 {
#             background-color:  #e5ffe5;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row3_col11 {
#             background-color:  #89cc89;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row3_col12 {
#             background-color:  #b3e3b3;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row3_col13 {
#             background-color:  #81c781;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row3_col14 {
#             background-color:  #77c277;
#         }    #T_23b217b6_fa2d_11e8_abbd_4ccc6a844414row3_col15 {
#             background-color:  #e5ffe5;
#         }    #T_23b217b6_fa2d_11e8_abbd_4cc

# %% [markdown]
# Based on the Heatmap, we remove currency variable because this variable is highly corelated with country (0.798)
# Moreover, backers and USD pledge real are also highly correlated, (0.82)

# %%
dataset.drop(columns = ["currency"], inplace =True)
dataset.drop(columns = ["backers"], inplace =True)

# %%
dataset.drop(columns = ["name"], inplace =True)

# %% [markdown]
# We also observed that number of letters and number of words in the company names are really high correlated. However, we're keeping them to test an RFE or Best K features.

# %%
dataset.drop(columns = ["usd_pledged_real"], inplace =True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43419 entries, 1 to 378654
# Data columns (total 17 columns):
# ID                                      43419 non-null int64
# main_category                           43419 non-null int64
# state                                   43419 non-null int64
# country                                 43419 non-null int64
# usd_goal_real                           43419 non-null int64
# hours                                   43419 non-null int64
# Month                                   43419 non-null int64
# length_of_campain                       43419 non-null int64
# Average_Pledge_Per_Category             43419 non-null float64
# Average_Goal_Per_Category               43419 non-null float64
# Average_NumberofBackers_Per_Category    43419 non-null float64
# Competitors                             43419 non-null int64
# Is_Above_Average                        43419 non-null int64
# Day_of_the_week                         43419 non-null int64
# Name_Number_Letters                     43419 non-null int64
# Number_of_words                         43419 non-null int64
# Av_Success_Rate_Per_Category            43419 non-null float64
# dtypes: float64(4), int64(13)
# memory usage: 6.0 MB

# %% [markdown]
# From this first selection we reorganise columns.

# %%
inserted_cols = ['ID','main_category','Name_Number_Letters','Number_of_words','country','hours','Day_of_the_week','Month','length_of_campain','usd_goal_real','Competitors','Average_Pledge_Per_Category','Average_Goal_Per_Category','Average_NumberofBackers_Per_Category','Av_Success_Rate_Per_Category','Is_Above_Average','state']
cols = ([col for col in inserted_cols if col in dataset] 
        + [col for col in dataset if col not in inserted_cols]) #Reogarnize columns to be more readable. 
dataset = dataset[cols]
dataset.head()
# Out:
#             ID  main_category  Name_Number_Letters  Number_of_words  country  \
# 1   1000003930              3                   45                8        1
# 14  1000057089              1                   57               10        2
# 21  1000081649              7                   32                4        4
# 29   100011318              3                   29                5        1
# 43  1000170964              1                   55               11        1
#
#     hours  Day_of_the_week  Month  length_of_campain  usd_goal_real  \
# 1       4                7      9                 60              9
# 14     19                4      4                 28              6
# 21      1                3      8                 30              3
# 29     17                2      4                 30             11
# 43      4                5      3                 25              2
#
#     Competitors  Average_Pledge_Per_Category  Average_Goal_Per_Category  \
# 1           397                       5808.0                   164850.0
# 14          592                      22930.0                    21266.0
# 21          396                       6042.0                    19000.0
# 29          513                       5808.0                   164850.0
# 43          691                      22930.0                    21266.0
#
#     Average_NumberofBackers_Per_Category  Av_Success_Rate_Per_Category  \
# 1                                   60.0                      0.422857
# 14                                 317.0                      0.524691
# 21                                  57.0                      0.349112
# 29                                  60.0                      0.449024
# 43                                 317.0                      0.538328
#
#     Is_Above_Average  state
# 1                  0      0
# 14                 0      1
# 21                 0      0
# 29                 0      1
# 43                 0      0

# %% [markdown]
# #### 5.4- Checking importance of data with KBEST and RFE

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %% [markdown]
# Define Output function Y and variables function X

# %%
dataset.shape
# Out:
# (43419, 17)

# %%
databest=dataset
array = databest.head()

# %%
X = array.iloc[:,0:16]
Y = array.iloc[:,16]
X.shape
# Out:
# (5, 16)

# %%
test = SelectKBest(score_func=chi2, k=10)
fitkbest = test.fit(X, Y)

# %%
np.set_printoptions(precision=1)
print(fitkbest.scores_)
features = fitkbest.transform(X)
# Out:
# [3.0e+08 1.1e+00 2.8e-02 4.4e-03 1.7e-01 3.0e+01 1.1e+00 1.5e+00 3.0e+00
#  2.8e+00 7.8e+00 7.3e+02 9.3e+03 1.4e+01 6.6e-03     nan]

# %%
print(features[0:11,:])
# Out:
# [[1.0e+09 4.0e+00 7.0e+00 9.0e+00 6.0e+01 9.0e+00 4.0e+02 5.8e+03 1.6e+05
#   6.0e+01]
#  [1.0e+09 1.9e+01 4.0e+00 4.0e+00 2.8e+01 6.0e+00 5.9e+02 2.3e+04 2.1e+04
#   3.2e+02]
#  [1.0e+09 1.0e+00 3.0e+00 8.0e+00 3.0e+01 3.0e+00 4.0e+02 6.0e+03 1.9e+04
#   5.7e+01]
#  [1.0e+08 1.7e+01 2.0e+00 4.0e+00 3.0e+01 1.1e+01 5.1e+02 5.8e+03 1.6e+05
#   6.0e+01]
#  [1.0e+09 4.0e+00 5.0e+00 3.0e+00 2.5e+01 2.0e+00 6.9e+02 2.3e+04 2.1e+04
#   3.2e+02]]

# %% [markdown]
# ###### RFE

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
rfe = RFE(model, 10)
fitrfe = rfe.fit(X, Y)
# Out:
# C:\Users\david\Anaconda3\envs\deeplearning\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning:
#
# Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#
# C:\Users\david\Anaconda3\envs\deeplearning\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning:
#
# Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#
# C:\Users\david\Anaconda3\envs\deeplearning\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning:
#
# Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#
# C:\Users\david\Anaconda3\envs\deeplearning\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning:
#
# Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#
# C:\Users\david\Anaconda3\envs\deeplearning\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning:
#
# Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#
# C:\Users\david\Anaconda3\envs\deeplearning\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning:
#
# Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#
# C:\Users\david\Anaconda3\envs\deeplearning\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning:
#
# Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.

# %%
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [ True False  True  True False  True False False  True  True  True  True
#   True  True False False]
# [1 2 1 1 3 1 6 5 1 1 1 1 1 1 4 7]

# %%
dataset.head()
# Out:
#             ID  main_category  Name_Number_Letters  Number_of_words  country  \
# 1   1000003930              3                   45                8        1
# 14  1000057089              1                   57               10        2
# 21  1000081649              7                   32                4        4
# 29   100011318              3                   29                5        1
# 43  1000170964              1                   55               11        1
#
#     hours  Day_of_the_week  Month  length_of_campain  usd_goal_real  \
# 1       4                7      9                 60              9
# 14     19                4      4                 28              6
# 21      1                3      8                 30              3
# 29     17                2      4                 30             11
# 43      4                5      3                 25              2
#
#     Competitors  Average_Pledge_Per_Category  Average_Goal_Per_Category  \
# 1           397                       5808.0                   164850.0
# 14          592                      22930.0                    21266.0
# 21          396                       6042.0                    19000.0
# 29          513                       5808.0                   164850.0
# 43          691                      22930.0                    21266.0
#
#     Average_NumberofBackers_Per_Category  Av_Success_Rate_Per_Category  \
# 1                                   60.0                      0.422857
# 14                                 317.0                      0.524691
# 21                                  57.0                      0.349112
# 29                                  60.0                      0.449024
# 43                                 317.0                      0.538328
#
#     Is_Above_Average  state
# 1                  0      0
# 14                 0      1
# 21                 0      0
# 29                 0      1
# 43                 0      0

# %% [markdown]
# Import libraries we'll need for XGboost and other models

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# %%
x = dataset.drop(columns = "state")
y = dataset.state

# %% [markdown]
# ### Split Train-Validation-Test

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
X_training,X_validation,Y_training,Y_validation = train_test_split(X_train,Y_train, test_size = 0.20, random_state = 42)
# Out:
# (27788, 16)

# %% [markdown]
# ### XGboost

# %%
#XGboost

xgb = XGBClassifier()
parameters = dict(model__max_depth=[3,5,9],
                  model__learning_rate=[.01,0.05, .1],
                  model__n_estimators=[100, 500])

                     
grid_search = GridSearchCV(xgb,param_grid = parameters,scoring='accuracy', verbose=1, cv=10)

# %%
grid_search.fit(X_training,Y_training)

# make predictions for test data
y_pred = grid_search.predict(X_validation)

accuracy = accuracy_score(Y_validation, y_pred)
print(accuracy)
# Out:
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:  5.8min finished
# 0.6781344465236793

# %% [markdown]
# ### Catboost

# %%
from catboost import CatBoostClassifier

# %%
clf = CatBoostClassifier(depth=6, iterations=1000, learning_rate=0.1, thread_count=16, logging_level='Silent')
clf.fit(X_training, Y_training)

# %%
Y_pred = clf.predict(X_validation)

# %%
accuracyCat = accuracy_score(Y_validation,Y_pred)
print(accuracyCat)
# Out:
# 0.6779904994961854
